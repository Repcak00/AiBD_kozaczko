# %% [markdown]
# # Zadanie nr 3
#
# Kacper Kozaczko 402162
#
# Ćwiczenie zostało wykonane na pierwszych laboratoriach AiBD. Poniżej widoczne są 3 wykresy wykonane dla zadanych argumentów

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas

function = lambda x: x**2 + 5

x1 = np.linspace(-1, 1)
x2 = np.linspace(-6, 6)
x3 = np.linspace(0, 5)

y1 = function(x1)
y2 = function(x2)
y3 = function(x3)

# %% [markdown]
# ## Przedział nr 1:
#
# $x>-1$ oraz $x<1$

# %%
plt.plot(x1, y1)
plt.ylabel('wartosci')
plt.xlabel('argumenty')
plt.title("Funkcja x^2 + 5 dla 1. przedzialu")
plt.legend(['x^2+5'])
plt.show()

# %% [markdown]
# ## Przedział nr 2:
#
# $x>-6$ oraz $x<6$

# %%
plt.plot(x2, y2)
plt.ylabel('wartosci')
plt.xlabel('argumenty')
plt.title("Funkcja x^2 + 5 dla 2. przedzialu")
plt.legend(['x^2+5'])
plt.show()

# %% [markdown]
# ## Przedział nr 3:
#
# $x>0$ oraz $x<5$

# %%
plt.plot(x3, y3)
plt.ylabel('wartosci')
plt.xlabel('argumenty')
plt.title("Funkcja x^2 + 5 dla 3. przedzialu")
plt.legend(['x^2+5'])

plt.show()

# %% [markdown]
# ## Zadanie nr 4

# %% [markdown]
# Stworzenie Datframe

# %%
dataFrame = pandas.DataFrame(np.array([['Kacper', 'Kozaczko', 21, 'man'], ['Jan', 'Kowalski', 32, 'man'], ['Anna', 'Bcd', 22, 'woman'], ['Andrzej', 'Pierwszy', 45, 'man'], ['Dorota', 'Serdek', 67, 'woman']]), 
                             columns=['name', 'surname', 'age', 'sex'])

# %%
dataFrame
# Out:
#       name   surname age    sex
# 0   Kacper  Kozaczko  21    man
# 1      Jan  Kowalski  32    man
# 2     Anna       Bcd  22  woman
# 3  Andrzej  Pierwszy  45    man
# 4   Dorota    Serdek  67  woman

# %% [markdown]
# Wyświetlenie informacji za pomocą pandas.info()

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      object
#  3   sex      5 non-null      object
# dtypes: object(4)
# memory usage: 288.0+ bytes

# %% [markdown]
# Wykorzystanie pandas.describe(), która to funkcja generuje statystykę dotyczącą odpowiedniej kolumny.

# %%
dataFrame.describe(include='all')
# Out:
#           name   surname age  sex
# count        5         5   5    5
# unique       5         5   5    2
# top     Dorota  Pierwszy  22  man
# freq         1         1   1    3

# %% [markdown]
# Wykorzystanie pandas.head() w celu wyświetlenia pierwszych 3 rekordów.

# %%
dataFrame.head(3)
# Out:
#      name   surname age    sex
# 0  Kacper  Kozaczko  21    man
# 1     Jan  Kowalski  32    man
# 2    Anna       Bcd  22  woman
